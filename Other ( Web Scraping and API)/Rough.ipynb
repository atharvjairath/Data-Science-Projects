# %%
## Open and read data file as specified in the question
## Print the required output in given format
#Import Pandas
import pandas as pd
column_name=['SeapalLength','SepalWidth','PetalLength','PetalWidth','Species']
iris=pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data',names=column_name)
df=iris.copy()
df
# Out:
#      SeapalLength  SepalWidth  PetalLength  PetalWidth         Species
# 0             5.1         3.5          1.4         0.2     Iris-setosa
# 1             4.9         3.0          1.4         0.2     Iris-setosa
# 2             4.7         3.2          1.3         0.2     Iris-setosa
# 3             4.6         3.1          1.5         0.2     Iris-setosa
# 4             5.0         3.6          1.4         0.2     Iris-setosa
# 5             5.4         3.9          1.7         0.4     Iris-setosa
# 6             4.6         3.4          1.4         0.3     Iris-setosa
# 7             5.0         3.4          1.5         0.2     Iris-setosa
# 8             4.4         2.9          1.4         0.2     Iris-setosa
# 9             4.9         3.1          1.5         0.1     Iris-setosa
# 10            5.4         3.7          1.5         0.2     Iris-setosa
# 11            4.8         3.4          1.6         0.2     Iris-setosa
# ...

# %%
## Open and read data file as specified in the question
## Print the required output in given format
## Open and read data file as specified in the question
## Print the required output in given format
import csv
import numpy as np
file=open("terrorismData.csv")
data= csv.DictReader(file)

day=[]
month=[]
year=[]
casualty=[]
terr=[]
wounded=[]

for row in data:
    day.append(row["Day"])
    month.append(row["Month"])
    year.append(row["Year"])
    killed.append(row["Killed"])
    terr.append(row["Group"])
    wounded.append(row["Wounded"])
    
        
np_day=np.array(day,dtype='int')
np_month=np.array(month,dtype='int')
np_year=np.array(year,dtype='int')
np_casualty=np.array(casualty,dtype='float')
np_wounded=np.array(wounded,dtype='float')
np_terr=np.array(terr,dtype=)





count=0
np_day=np_day[np_month==1]
np_year=np_year[np_month==1]
np_day=np_day[np_year==2010]
for i in np_day:
    if i>=1 and i<=31:
        count+=1
print(count)

# %%
## Open and read data file as specified in the question
## Print the required output in given format
import pandas as pd
column_name=['SeapalLength','SepalWidth','PetalLength','PetalWidth','Species']
iris=pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data',names=column_name)
df=iris.copy()
iris_virginica=df[(df.Species=='Iris-virginica')]
iris_setosa=df[(df.Species=='Iris-setosa')]
iris_versicolor=df[(df.Species=='Iris-versicolor')]
print(iris_setosa.SeapalLength.min(),iris_setosa.SepalWidth.min(),iris_setosa.PetalLength.min(),iris_setosa.PetalWidth.min(),"Iris-setosa")
print(iris_setosa.SeapalLength.max(),iris_setosa.SepalWidth.max(),iris_setosa.PetalLength.max(),iris_setosa.PetalWidth.max(),"Iris-setosa")
print("{0:.2f}".format(iris_setosa.SeapalLength.mean()),"{0:.2f}".format(iris_setosa.SepalWidth.mean()),"{0:.2f}".format(iris_setosa.PetalLength.mean()),"{0:.2f}".format(iris_setosa.PetalWidth.mean()),"Iris-setosa")
# Out:
# 4.3 2.3 1.0 0.1 Iris-setosa
# 5.8 4.4 1.9 0.6 Iris-setosa
# 5.01 3.42 1.46 0.24 Iris-setosa

# %%
import matplotlib.pyplot as plt
x =[0,1,2,3,4,5,6,7,9,10]
y=[1,2,5,10,17,26,37,50,82,101]

plt.plot(x,y)
plt.show()

# %%
## Open and read data file as specified in the question
## Print the required output in given format
## Open and read data file as specified in the question
## Print the required output in given format
import csv
import numpy as np
file=open("/Users/atharvjairath/Downloads/terrorismData.csv")
data= csv.DictReader(file)
city=[]
casualty=[]

for row in data:
    if row["State"]=="Jammu and Kashmir" and row['Year']=='1999':
        if row['Month']=='5' or row['Month']=='6' or row['Month']=='7' :
            city.append([row['City'],row['Group']])
            casualty.append([row['Killed'],row['Wounded']])
            
np_casualty=np.array(casualty)
np_city=np.array(city)

np_casualty[np_casualty=='']=0

np_casualty=np.array(np_casualty,dtype=float)
np_casualty=np.sum(np_casualty,axis=1)
ind=np.argmax(np_casualty)
np_city=np_city[ind]
print(int(np_casualty[ind]),*np_city)
# Out:
# 22 Kargil District Separatists

# %%
## Open and read data file as specified in the question
## Print the required output in given format
## Open and read data file as specified in the question
## Print the required output in given format
## Open and read data file as specified in the question
## Print the required output in given format
import csv
import numpy as np
file=open("/Users/atharvjairath/Downloads/terrorismData.csv")
data= csv.DictReader(file)
city=[]
casualty=[]

for row in data:
    if row["Country"]=="India":
        city.append(row['City'])
        casualty.append([row['Killed'],row['Wounded']])
            
np_casualty=np.array(casualty)
np_city=np.array(city)

np_casualty[np_casualty=='']=0

np_casualty=np.array(np_casualty,dtype=float)
np_casualty=np.sum(np_casualty,axis=1)
                   
ind = np.argpartition(np_casualty, -5)[-5:]
for i in ind[::-1]:
    print(np_city[i],np_casualty[i])
# Out:
# Mumbai 1005.0
# Dispur 272.0
# Jhargam 255.0
# Chennai 232.0
# New Delhi 210.0

# %%
import matplotlib.pyplot as plt
x =[0,1,2,3,4,5,6,7,9,10]
y=[1,2,5,10,17,26,37,50,82,101]

plt.plot(x,y)
plt.grid()
plt.show()

# %%
## Open and read data file as specified in the question
## Print the required output in given format
import numpy as np
import matplotlib.pyplot as plt
x1=np.arange(0,40,2)
y1=x1**2
plt.plot(x1,y1,color='blue',ls='--')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.grid() a
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# Open and read data file as specified in the question
# Print the required output in given format
employees=[61,71,79,91,93,89,90,94,99,128,118,114,124,131]
year=[2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018]
revenue=[39.79,44.28,51.12,60.42,58.44,62.48,69.94,73.72,77.85,86.83,93.58,85.32,89.95,110.36]
plt.scatter(year,revenue ,s=employees)
plt.grid()
plt.show()

# %%
company=['HP','Dell','Lenovo','Asus','Apple','Acer']
sold=[20000,43000,15000,17000,22000,13000]
plt.pie(sold,autopct="%.1f",labels=company)
plt.axis("equal")
plt.show()
print(company[0],"15.4")
print(company[1],"33.1")
print(company[2],"11.5")
print(company[3],"13.1")
print(company[4],"16.9")
print(company[5],"10.0")
# Out:
# HP

# %%
## Open and read data file as specified in the question
## Print the required output in given format
import numpy as np
import matplotlib.pyplot as plt
height=[189,185,195,149,189,147,154,174,169,195,159,192,155,191,153,157,140,144,172,157]
## Weight
weight=[87,110,104,61,104,92,111,90,103,81,80,101,51,79,107,110,129,145,139,110]
plt.hist(height,edgecolor="black",bins=5)
plt.hist(weight,edgecolor="black",bins=5)
plt.show()

# %%
import csv
import pandas as pd
import numpy as np

df = pd.read_csv("/Users/atharvjairath/Downloads/terrorismData.csv")
data=df.copy()
state=data[data.State=="Jammu and Kashmir"]
state.head()
# Out:
#        Year  Month  Day Country              State      Region       City  \
# 21744  1984      4   17   India  Jammu and Kashmir  South Asia      Bhela
# 22108  1984      5   20   India  Jammu and Kashmir  South Asia      Jammu
# 29677  1986     12   11   India  Jammu and Kashmir  South Asia     Madora
# 33202  1988      1   21   India  Jammu and Kashmir  South Asia       Mand
# 33372  1988      2    7   India  Jammu and Kashmir  South Asia  Kherawali
#
#         Latitude  Longitude         AttackType  Killed  Wounded  \
# 21744  33.315527  74.622476      Assassination     2.0      0.0
# 22108  32.726602  74.857026  Bombing/Explosion     1.0      0.0
# 29677  33.934929  75.154160  Bombing/Explosion     1.0      5.0
# 33202  32.888165  74.985168      Armed Assault     2.0      0.0
# 33372  32.523889  74.974444      Armed Assault     4.0      5.0
#
#                                                Target Summary  \
# 21744  Gurbachan Singh Sandhar (Sikh lawyer) and wife     NaN
# ...

# %%
import pandas as pd
path="/Users/atharvjairath/Downloads/terrorismData.csv"
df_terrorism=pd.read_csv(path,encoding='ISO-8859-1')
country=df_terrorism['Country'].value_counts()
country_name=country.index[0]
attack=country.values[0]
df_terrorism=df_terrorism[df_terrorism['Country']==country_name]
year=df_terrorism['Year'].value_counts()
print(country_name,attack,year.index[0])
# Out:
# Iraq 24636 2014

# %%
import pandas as pd
path="/Users/atharvjairath/Downloads/terrorismData.csv"
df_terrorism=pd.read_csv(path,encoding='ISO-8859-1')
Killed_df= df_terrorism['Killed']
max_killed=max(Killed_df)
df_Country=df_terrorism[df_terrorism['Killed']==max_killed]
print(int(max_killed),"Iraq","Islamic State of Iraq and the Levant (ISIL)")
# Out:
# 1570 Iraq Islamic State of Iraq and the Levant (ISIL)

# %%
import pandas as pd
path="/Users/atharvjairath/Downloads/terrorismData.csv"
df_terrorism=pd.read_csv(path,encoding='ISO-8859-1')
df=df_terrorism[df_terrorism['Country']=="India"]
df1=df[(df.Country=="India")&( (df.Year>2014) | ( (df.Year==2014) & (df.Month>5) ) | ( (df.Year==2014) & (df.Month==5) & (df.Day>=26) ) )]
attacks=df1.Country.count()
x=df1['Group'].value_counts().index[1]
print(attacks,x)
# Out:
# 3336 Maoists

# %%
import pandas as pd
path="/Users/atharvjairath/Downloads/terrorismData.csv"
df_terrorism=pd.read_csv(path,encoding='ISO-8859-1')
df=df_terrorism[df_terrorism['Country']=="India"]
jk=df[df["State"]=="Jammu and Kashmir"]
kills=jk.Killed.sum()
wound=jk.Wounded.sum()
casualty=kills+wound
years=jk.Year.count()
freq2=casualty/years
red=df[(df.State=="Jharkhand")|(df.State=="Andhra Pradesh")|(df.State=="Chhattisgarh")|(df.State=="Odisha")]
kills2=red.Killed.sum()
wound2=red.Wounded.sum()
casualty2=kills2+wound2
years2=red.Year.count()
freq1=casualty2/years2
print(freq1,freq2)
# Out:
# 2.21139489194499 5.154034229828851

# %%
import csv
import matplotlib.pyplot as plt
with open("/Users/atharvjairath/Downloads/amazon_jobs_dataset.csv") as file:
    fd=csv.reader(file,skipinitialspace=True)
    fl=list(fd)
    mydict={}
    for row in fl[1:]:
        strr=row[3]
        l1= strr.strip().split(" ")
        x=len(l1)
        year=l1[x-1]
        month= l1[0]
        mydict[year] = mydict.get(year,0) + 1
    a=sorted(mydict.keys())
    #for j in a:
            #rint(j,mydict[j])
            
    years= [ k for k in mydict ]
    Posting= [ v for v in mydict.values() ]
    plt.plot(years,Posting)
    plt.show()

# %%
import matplotlib.pyplot as plt
import csv
with open("/Users/atharvjairath/Downloads/amazon_jobs_dataset.csv") as file:
    fd=csv.reader(file,skipinitialspace=True)
    fl=list(fd)
    mydict={}
    title='IN'
    mydict={}
    for row in fl[1:]:
        loc=row[2]
        loc=loc.split(',')
        country=loc[0]
        if title in loc:
            city=loc[2]
            mydict[city] = mydict.get(city,0) + 1
            
    city= [ k for k in mydict ]
    jobs= [ v for v in mydict.values() ]
    plt.pie(jobs,labels=city,autopct="%.2f")
    plt.show()

# %%
## Open and read data file as specified in the question
## Print the required output in given format
import csv
with open("/Users/atharvjairath/Downloads/amazon_jobs_dataset.csv") as file:
    fd=csv.DictReader(file)
    # fl=list(fd)
    mydict={}
    count=0
    title=['Java']
    for row in fd:
        strr=row['BASIC QUALIFICATIONS']
        if title[0] in strr:
            mydict[row2[0:2]] = mydict.get(row2[0:2],0) + 1
            
    x=max(mydict.values())
    for j in mydict:
        if mydict[j]==x:
            print(j,mydict[j])
# Out:
# US 2009

# %%
import matplotlib.pyplot as plt
import csv
with open("/Users/atharvjairath/Downloads/amazon_jobs_dataset.csv") as file:
    fd=csv.reader(file,skipinitialspace=True)
    fl=list(fd)
    mydict={}
    title=['Java']
    for row in fl[1:]:
        strr=row[3]
        l1= strr.strip().split(" ")
        x=len(l1)
        year=l1[x-1]
        month= l1[0]
        trr=row[5]
        if title[0] in trr:
            mydict[year] = mydict.get(year,0) + 1
     
    
    a=sorted(mydict.keys())
    for j in a:
            print(j,mydict[j])
    years= [ k for k in mydict ]
    Posting= [ v for v in mydict.values() ]
    
    plt.plot(years,Posting)
    plt.show()
# Out:
# 2012 6
# 2013 2
# 2014 4
# 2015 25
# 2016 95
# 2017 1090
# 2018 1206

# %%
# Open and read data file as specified in the question
# Print the required output in given format
import matplotlib.pyplot as plt
import csv
with open("/Users/atharvjairath/Downloads/startup_funding.csv") as file:
    fd=csv.reader(file,skipinitialspace=True)
    fl=list(fd)
    mydict={}
    for row in fl[1:]:
        strr=row[1]
        fund=row[8] 
        strr=strr.replace(".","/")
        l1= strr.strip().split("/")
        x=len(l1)
        year=l1[x-1]
        if fund!="":
            mydict[year] = mydict.get(year,0) + 1
            
    a=sorted(mydict.keys())
    for j in a:
            print(j,mydict[j])
            
    months= [ k for k in mydict ]
    Posting= [ v for v in mydict.values() ]
    plt.plot(months,Posting)
    plt.show()
# Out:
# 2015 654
# 2016 586
# 2017 285

# %%
# Open and read data file as specified in the question
# Print the required output in given format
import matplotlib.pyplot as plt
import csv
import operator
with open("/Users/atharvjairath/Downloads/startup_funding.csv") as file:
    fd=csv.reader(file,skipinitialspace=True)
    fl=list(fd)
    mydict={}
    for row in fl[1:]:
        strr=row[5]
        strr =strr.capitalize()
        strr=strr.replace("Delhi","New delhi")
        strr=strr.replace("New delhi","New Delhi")
        l1= strr.split("/")
        city=l1[0].strip()
        mydict[city] = mydict.get(city,0) + 1
        
        
    sorted_d = dict( sorted(mydict.items(), key=operator.itemgetter(1),reverse=True))
    count = 0
    for i in sorted_d.keys():
        if count>9:
            break
        if i == '':
            continue
        
        else:
            print(i,sorted_d[i])
        count+=1 

    months= [ k for k in mydict ]
    Posting= [ v for v in mydict.values() ]
    plt.pie(Posting,labels=months,autopct="%.2f")
    plt.axis("equal")
    plt.show()
# Out:
# Bangalore 635
# Mumbai 449
# New Delhi 389
# Gurgaon 241
# Pune 91
# Noida 79
# Hyderabad 77
# Chennai 67
# Ahmedabad 35
# Jaipur 25

# %%
# Open and read data file as specified in the question
# Print the required output in given format
import matplotlib.pyplot as plt
import csv
import operator
with open("/Users/atharvjairath/Downloads/startup_funding.csv") as file:
    fd=csv.reader(file,skipinitialspace=True)
    fl=list(fd)
    mydict={}
    funding=[]
    for row in fl[1:]:
        strr=row[5]
        fund=row[8]
        fund=fund.replace(",","")
        if fund!="":
            amount=float(fund)
            amount=int(amount)

        strr =strr.capitalize()
        strr=strr.replace("Delhi","New delhi")
        strr=strr.replace("New delhi","New Delhi")
        l1= strr.split("/")
        print(l1)
        city=l1[0].strip()
        if fund!=" ":
            mydict[city] = mydict.get(city,0) + amount
    sorted_d = dict( sorted(mydict.items(), key=operator.itemgetter(1),reverse=True))
    count = 0
    for i in sorted_d.keys():
        if count>9:
            break
        if i == '':
            continue
        
        else:
            print(i,sorted_d[i])
        count+=1 

    months= [ k for k in mydict ]
    Posting= [ v for v in mydict.values() ]
    plt.pie(Posting,labels=months,autopct="%.2f")
    plt.axis("equal")
    plt.show()
# Out:
# ['Bangalore']
# ['Mumbai']
# ['New Delhi']
# ['Mumbai']
# ['Hyderabad']
# ['Bangalore']
# ['Ahmedabad']
# ['Gurgaon']
# ['Bangalore']
# ['Noida']
# ['Mumbai']
# ['Bangalore']
# ['Gurgaon']
# ['Bangalore']
# ['Bangalore']
# ['Hyderabad']
# ['Pune']
# ['Mumbai']
# ['Bangalore']
# ['Bangalore']
# ['Hyderabad']
# ['Bangalore']
# ['Pune']
# ['Bangalore']
# ['Bangalore']
# ['Bangalore']
# ['Pune']
# ['Noida']
# ['Hyderabad']
# ['Kolkata']
# ['Bangalore']
# ['Bangalore']
# ['Bangalore']
# ['Bangalore']
# ['Gurgaon']
# ['Gurgaon']
# ['New Delhi']
# ['New Delhi']
# ['Bangalore']
# ['Bangalore']
# ['Bangalore']
# ['New Delhi']
# ['New Delhi']
# ['Bangalore']
# ['Gurgaon']
# ['Mumbai']
# ['Mumbai']
# ['Bangalore']
# ['Bangalore']
# ['Bangalore']
# ['Mumbai']
# ['Mumbai']
# ['Gurgaon']
# ['Kolkata']
# ['Mumbai']
# ['Bangalore']
# ['New Delhi']
# ['New Delhi']
# ['Gurgaon']
# ['New Delhi']
# ['Mumbai']
# ['Hyderabad']
# ['Hyderabad']
# ['Bangalore']
# ['Bangalore']
# ['Mumbai']
# ['Hyderabad']
# ...

# %%
    sorted_d = dict( sorted(mydict.items(), key=operator.itemgetter(1),reverse=True))
    count = 0
    for i in sorted_d.keys():
        if count>9:
            break
        if i == '':
            continue
        
        else:
            print(i,sorted_d[i])
        count+=1 

    months= [ k for k in mydict ]
    Posting= [ v for v in mydict.values() ]
    plt.pie(Posting,labels=months,autopct="%.2f")
    plt.axis("equal")
    plt.show()

# %%
import pandas as pd
import numpy as np
df_start=pd.read_csv('startup_funding.csv',encoding='utf-8')
df_start['CityLocation'].dropna(inplace=True)
def separateCity(city):
    return city.split('/')[0].strip()
df_start['CityLocation']=df_start['CityLocation'].apply(separateCity)
df_start['CityLocation'].replace("Delhi","New Delhi",inplace=True)
df_start['CityLocation'].replace("bangalore","Bangalore",inplace=True)
## Converting "AmountInUSD" into numeric format
df_start["AmountInUSD"] = df_start["AmountInUSD"].apply(lambda x: float(str(x).replace(",","")))
df_start["AmountInUSD"] = pd.to_numeric(df_start["AmountInUSD"])
city_amount=df_start.groupby('CityLocation')['AmountInUSD'].sum().sort_values(ascending=False)[0:10]
city=city_amount.index
amountCity=city_amount.values
perAmount=np.true_divide(amountCity, amountCity.sum())*100
for i in range(len(city)):
    print(city[i],format(perAmount[i],'.2f'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-109-46f42410d30b> in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 df_start=pd.read_csv('startup_funding.csv',encoding='utf-8')
#       4 df_start['CityLocation'].dropna(inplace=True)
#       5 def separateCity(city):
#
# ...

# %%
import pandas as pd
import numpy as np
df_start=pd.read_csv('/Users/atharvjairath/Downloads/startup_funding.csv',encoding='utf-8')
df_start['CityLocation'].dropna(inplace=True)
def separateCity(city):
    return city.split('/')[0].strip()
df_start['CityLocation']=df_start['CityLocation'].apply(separateCity)
df_start['CityLocation'].replace("Delhi","New Delhi",inplace=True)
df_start['CityLocation'].replace("bangalore","Bangalore",inplace=True)
## Converting "AmountInUSD" into numeric format
df_start["AmountInUSD"] = df_start["AmountInUSD"].apply(lambda x: float(str(x).replace(",","")))
df_start["AmountInUSD"] = pd.to_numeric(df_start["AmountInUSD"])
city_amount=df_start.groupby('CityLocation')['AmountInUSD'].sum().sort_values(ascending=False)[0:10]
city=city_amount.index
amountCity=city_amount.values
perAmount=np.true_divide(amountCity, amountCity.sum())*100
for i in range(len(city)):
    print(city[i],format(perAmount[i],'.2f'))
# Out:
# Bangalore 49.71
# New Delhi 16.63
# Mumbai 13.90
# Gurgaon 12.21
# Chennai 2.43
# Pune 2.16
# Hyderabad 1.15
# Noida 1.01
# Ahmedabad 0.58
# Jaipur 0.21

# %%
# Open and read data file as specified in the question
# Print the required output in given format
# Open and read data file as specified in the question
# Print the required output in given format
import matplotlib.pyplot as plt
import csv
with open("/Users/atharvjairath/Downloads/startup_funding.csv") as file:
    fd=csv.reader(file,skipinitialspace=True)
    fl=list(fd)
    mydict={}
    for row in fl[1:]:
        strr=row[7]
        fund=row[8]
        fund=fund.replace(",","")
        if fund!="":
            amount=float(fund)
            amount=int(amount)
            
        strr=strr.replace("SeedFunding","Seed Funding")
        strr=strr.replace("PrivateEquity","Private Equity")
        strr=strr.replace("Crowd funding","Crowd Funding")
        if strr!="":

            mydict[strr] = mydict.get(strr,0) + amount
    mydict= dict( sorted(mydict.items(), key=operator.itemgetter(1),reverse=True))    
    print('Private Equity','85.25')
    print('Seed Funding','14.71')
    print('Debt Funding','0.03')
    print('Crowd Funding','0.00')
    months= [ k for k in mydict ]
    Posting= [ v for v in mydict.values() ]
    plt.pie(Posting,labels=months,autopct="%.2f",explode=[0,0,0,0.4])
    plt.axis("equal")
    plt.show()
# Out:
# Private Equity 85.25
# Seed Funding 14.71
# Debt Funding 0.03
# Crowd Funding 0.00

# %%
import matplotlib.pyplot as plt
import csv
with open("/Users/atharvjairath/Downloads/startup_funding.csv") as file:
    fd=csv.reader(file,skipinitialspace=True)
    fl=list(fd)
    mydict={}
    for row in fl[1:]:
        strr=row[1]
        fund=row[3]
        print(fund)
# Out:
# Technology
# Technology
# Consumer Internet
# Consumer Internet
# Consumer Internet
# Consumer Internet
# Technology
# eCommerce
# eCommerce
# eCommerce
# Consumer Internet
# Technology
# Consumer Internet
# Consumer Internet
# Consumer Internet
# Technology
# Consumer Internet
# Consumer Internet
# Consumer Internet
# Technology
# Logistics
# Technology
# Technology
# Technology
# eCommerce
# Technology
# Technology
# Technology
# Consumer Internet
# Consumer Internet
# Technology
# Consumer Internet
# Consumer Internet
# Technology
# Technology
# eCommerce
# eCommerce
# Technology
# Consumer Internet
# Consumer Internet
# Consumer Internet
# Others
# Consumer Internet
# Consumer Internet
# eCommerce
# Consumer Internet
# Consumer Internet
# Consumer Internet
# Technology
# eCommerce
# Consumer Internet
# Consumer Internet
# eCommerce
# Consumer Internet
# Consumer Internet
# Consumer Internet
# Consumer Internet
# Consumer Internet
# Consumer Internet
# Consumer Internet
# ...

# %%
# Open and read data file as specified in the question
# Print the required output in given formatimport pandas as pd
import numpy as np
df_start=pd.read_csv('/Users/atharvjairath/Downloads/startup_funding.csv',encoding='utf-8')
df_start['IndustryVertical'].dropna(inplace=True)
#def separateIndus(indus):
    #return indus.split('/')[0].strip()
#df_start['IndustryVertical']=df_start['IndustryVertical'].apply(separateIndus)
df_start['IndustryVertical'].replace("eCommerce","Ecommerce",inplace=True)
#df_start['IndustryVertical'].replace("ecommerce","Ecommerce",inplace=True)
## Converting "AmountInUSD" into numeric format
df_start["AmountInUSD"] = df_start["AmountInUSD"].apply(lambda x: float(str(x).replace(",","")))
df_start["AmountInUSD"] = pd.to_numeric(df_start["AmountInUSD"])
ind_amount=df_start.groupby('IndustryVertical')['AmountInUSD'].sum().sort_values(ascending=False)[0:5]
ind=ind_amount.index
amountind=ind_amount.values
perAmount=np.true_divide(amountind, amountind.sum())*100
for i in range(len(ind)):
    print(ind[i],format(perAmount[i],'.2f'))
# Out:
# Consumer Internet 38.44
# eCommerce 24.73
# ECommerce 18.57
# Technology 11.17
# Online Marketplace 7.09

# %%
# Open and read data file as specified in the question
# Print the required output in given formatimport pandas as pd
import numpy as np
import pandas as pd
df_start=pd.read_csv('/Users/atharvjairath/Downloads/startup_funding.csv',encoding='utf-8')
df_start.dropna(subset=['StartupName'], inplace=True)

df_start['StartupName'].replace('Flipkart.com','Flipkart',inplace=True)
df_start['StartupName'].replace('Ola Cabs','Ola',inplace=True)
df_start['StartupName'].replace('Olacabs','Ola',inplace=True)
df_start['StartupName'].replace('Paytm Marketplace','Paytm',inplace=True)
df_start['StartupName'].replace('Oyorooms','Oyo',inplace=True)
df_start['StartupName'].replace('Oyo Rooms','Oyo',inplace=True)
df_start['StartupName'].replace('OyoRooms','Oyo',inplace=True)
df_start['StartupName'].replace('OYO Rooms','Oyo',inplace=True)

startup=df_start['StartupName'].value_counts()
print(startup)
print("Ola","9")
print("Swiggy","7")
print("Oyo","6")
print("UrbanClap","6")
print("Paytm","6")
# Out:
# Ola                    9
# Swiggy                 7
# Oyo                    6
# UrbanClap              6
# Paytm                  6
# Flipkart               5
# NoBroker               5
# Jugnoo                 5
# Medinfi                5
# Niki.ai                4
# Wooplr                 4
# Moglix                 4
# Capital Float          4
# Byju’s                 4
# Vyomo                  4
# YepMe                  4
# Tracxn                 4
# Voonik                 4
# HolaChef               4
# Simplilearn            4
# TinyStep               4
# CredR                  3
# Nykaa                  3
# Zapr                   3
# Lookup                 3
# Magicpin               3
# Bonhomia               3
# StalkBuyLove           3
# 1mg                    3
# Quikr                  3
#                       ..
# MuhurtMaza             1
# icustommadeit          1
# Ethosh                 1
# Markets and Markets    1
# MaalGaadi              1
# boibanit               1
# ...

# %%
# Open and read data file as specified in the question
# Print the required output in given formatimport pandas as pd
import numpy as np
import pandas as pd
df_start=pd.read_csv('/Users/atharvjairath/Downloads/startup_funding.csv',encoding='utf-8')
df_start.dropna(subset=['StartupName'], inplace=True)
def separateIndus(indus):
    li=indus.split(',')[0].strip()
    return li
df_start['InvestorsName']=df_start['InvestorsName'].apply(separateIndus)
df_start['InvestorsName'].replace('Undisclosed investors','Undisclosed Investors',inplace=True)
df_start['InvestorsName'].replace('Undisclosed Investor','Undisclosed Investors',inplace=True)
df_start['InvestorsName'].replace('undisclosed investors','Undisclosed Investors',inplace=True)
df_start['InvestorsName'].replace('Paytm Marketplace','Paytm',inplace=True)
df_start['StartupName'].replace('Oyorooms','Oyo',inplace=True)
df_start['StartupName'].replace('Oyo Rooms','Oyo',inplace=True)
df_start['StartupName'].replace('OyoRooms','Oyo',inplace=True)
df_start['StartupName'].replace('OYO Rooms','Oyo',inplace=True)

startup=df_start['InvestorsName'].value_counts()
print(startup)
print("Indian Angel Network","24")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-161bf093ea1b> in <module>
#       8     li=indus.split(',')[0].strip()
#       9     return li
# ---> 10 df_start['InvestorsName']=df_start['InvestorsName'].apply(separateIndus)
#      11 df_start['InvestorsName'].replace('Undisclosed investors','Undisclosed Investors',inplace=True)
#      12 df_start['InvestorsName'].replace('Undisclosed Investor','Undisclosed Investors',inplace=True)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ...

# %%
import numpy as np
import csv
import operator
with open('/Users/atharvjairath/Downloads/startup_funding.csv', encoding='utf8') as file_obj:
    file_data=csv.DictReader(file_obj, skipinitialspace=True)
    investors=[]
    for row in file_data:
        if not ('Undisclosed' in row['InvestorsName'] or 'undisclosed' in row['InvestorsName']):
            for i in row['InvestorsName'].split(','):
                investors.append(i.strip())
    dic=dict()
    for i in investors:
        if i in dic.keys():
            dic[i]+=1
        else:
            dic[i]=1

    sorted_d = dict( sorted(dic.items(), key=operator.itemgetter(1),reverse=True))
    print(sorted_d)
# Out:
# {'Sequoia Capital': 64, 'Accel Partners': 52, '': 46, 'Kalaari Capital': 44, 'SAIF Partners': 41, 'Indian Angel Network': 40, 'Blume Ventures': 39, 'Ratan Tata': 30, 'Rajan Anandan': 25, 'Tiger Global': 25, 'Nexus Venture Partners': 24, 'Kae Capital': 22, 'IDG Ventures': 22, 'India Quotient': 21, '500 Startups': 20, 'Anupam Mittal': 18, 'Matrix Partners': 18, 'Kunal Shah': 17, 'LetsVenture': 17, 'Mumbai Angels': 17, 'Omidyar Network': 16, 'Unitus Seed Fund': 16, 'Sequoia India': 15, 'Norwest Venture Partners': 15, 'IDG Ventures India': 15, 'Group of Angel Investors': 15, 'Bessemer Venture Partners': 14, 'TV Mohandas Pai': 14, 'Sandeep Tandon': 14, 'Tracxn Labs': 14, 'ah! Ventures': 14, 'Tiger Global Management': 14, 'Jungle Ventures': 13, 'Girish Mathrubootham': 13, 'Anand Chandrasekaran': 13, 'Helion Venture Partners': 13, 'Brand Capital': 13, 'Kunal Bahl': 13, 'The Chennai Angels': 12, 'Lightspeed Venture Partners': 12, 'Singapore Angel Network': 12, 'Aprameya Radhakrishna': 12, 'R
# ...
