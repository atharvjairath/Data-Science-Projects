# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
arg=StandardScaler()


def run():
    data=np.loadtxt("training_boston_x_y_train.csv",delimiter=',')
    df=pd.DataFrame(data)
    
    y=df[13]
    df.drop(13,axis=1,inplace=True)
    features=df.columns
    b=13
    for a in features:
        df[b]=df[a]*df[a]
        b+=1
    c=26
    for a in features:
        df[c]=df[a]*df[a]*df[a]
        c+=1
        
    
    df[39]=y
    
    data=np.array(df)
    
    iteration=5000
    learning_rate=0.08
    
    
    m=gd(data,learning_rate,iteration)
    return m
def cost(x,y,m):
    return (1/len(x))*(((y-((x*m).sum(axis=1)))**2).sum())


def gd(points,learning_rate,iteration):
    m=np.zeros(points.shape[1])
    y_train=points[:,-1]
    
    
    x_train=points[:,:-1]
    x_train=arg.fit_transform(x_train)
    #x_train=arg.fit_transform(x_train)
    temp=np.ones((points.shape[0],points.shape[1]))
    temp[:,:-1]=x_train           
    x_train=temp
   
    for i in range(iteration):
        m=getmc(x_train,y_train,learning_rate,m)
     
        print(cost(x_train,y_train,m))
    return m

def getmc(x_train,y_train,learning_rate,m):
    scope_m=np.zeros(len(m))
   
    
    n=len(x_train)
    
    for i in range(n):
        
        for j in range(len(m)):
            scope_m[j]+=(-2/n)*((y_train[i]-(x_train[i]*m).sum())*x_train[i][j])
        
       
    new_m=m-learning_rate*scope_m
    
    return new_m
m=run()

#print(m)
test_data=np.loadtxt('boston_x_test.csv',delimiter=',')
df=pd.DataFrame(test_data)
    
    
features=df.columns
b=13
for a in features:
    df[b]=df[a]*df[a]
    b+=1
c=26
for a in features:
    df[c]=df[a]*df[a]*df[a]
    c+=1
    
    
test_data=np.array(df)
test_data=arg.transform(test_data)




#test_data=arg.transform(test_data)
amp=np.ones((test_data.shape[0],test_data.shape[1]+1))
amp[:,:-1]=test_data
test_data=amp

def pred(m,test_data):
    return (m*test_data).sum(axis=1)
        
    
a=pred(m,test_data)
np.savetxt('boston3.csv',a,delimiter=',')
print(a)
# Out:
# 416.49579188209765
# 296.31373352564674
# 213.83658553947097
# 156.41522254759664
# 116.17138137805017
# 87.85779893643135
# 67.88320367108683
# 53.75810953144453
# 43.745428247724696
# 36.62864830508889
# 31.553944890832764
# 27.9211594365887
# 25.30796287165933
# 23.41688048315606
# 22.03819326396793
# 21.023915319827
# 20.269519712140884
# 19.70109450179747
# 19.266309047729457
# 18.928056338810922
# 18.659976141609114
# 18.44330086614632
# 18.264632158200985
# 18.114372716398226
# 17.985619596666073
# 17.873382697494232
# 17.77403248255173
# 17.684909379605898
# 17.604047261735417
# 17.529977469608884
# 17.461589727811234
# 17.39803327705997
# 17.33864645434301
# 17.28290641390058
# 17.230393122201697
# 17.18076348125541
# 17.133732649070414
# 17.089060483346103
# 17.046541639859587
# 17.005998284713638
# 16.96727468193255
# 16.93023313171374
# 16.894750885967085
# 16.86071777494977
# 16.828034354777415
# 16.796610439502714
# 16.766363919753193
# 16.737219797170667
# 16.709109383316726
# 16.681969625579963
# 16.655742532552576
# 16.630374678476905
# 16.605816771503406
# 16.582023274223875
# 16.558952067652054
# 16.536564151807248
# 16.514823377519452
# 16.493696205162724
# 16.473151486840887
# 16.45316026917038
# 16.433695614282016
# 16.41473243703507
# 16.396247356730232
# 16.378218561843003
# 16.36062568648984
# 16.34344969749655
# 16.326672791069765
# 16.310278298183
# 16.29425059788398
# 16.278575037811358
# 16.263237861280555
# 16.248226140360963
# 16.23352771442192
# 16.219131133674114
# 16.205025607276852
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-8f8263dba3bf> in <module>
#      69
#      70     return new_m
# ---> 71 m=run()
#      72
#      73 #print(m)
#
# <ipython-input-1-8f8263dba3bf> in run()
#      30
#      31
# ---> 32     m=gd(data,learning_rate,iteration)
#      33     return m
#      34 def cost(x,y,m):
#
# <ipython-input-1-8f8263dba3bf> in gd(points, learning_rate, iteration)
#      49
#      50     for i in range(iteration):
# ---> 51         m=getmc(x_train,y_train,learning_rate,m)
#      52
#      53         print(cost(x_train,y_train,m))
#
# <ipython-input-1-8f8263dba3bf> in getmc(x_train, y_train, learning_rate, m)
#      63
#      64         for j in range(len(m)):
# ---> 65             scope_m[j]+=(-2/n)*((y_train[i]-(x_train[i]*m).sum())*x_train[i][j])
#      66
#      67
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      36 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      37          initial=_NoValue, where=True):
# ---> 38     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      39
#      40 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# KeyboardInterrupt:
